# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# pLsa는 sla를 개선한 것

# %% [markdown]
# - 각각의 문서는 혼합된 주제로, 각 주제는 혼합된 단어로 이루어져있다는 가정을 전제로 모델링한다

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 빨간색 T자가 topic인데, 즉, 저 네모는 토픽 단위로 구성됐다는 뜻

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 이항분포에서는 베타분포를, 다항 분포에서는 디리클레 분포를 사용한다
# - 지속적으로 단어 분포들의 사후 확률 분포를 업데이트가 포인트

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 세타와 에타는 사후 확률로 계속 업데이트 된다.

# %% [markdown]
# ![image.png](attachment:image.png)
# - LDA는 확률 기반이다 보니, 단순 count기반으로 연산

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - 토픽 갯수 정하는 것이 가장 어렵다(결과가 잘 안맞는 경우가 있기에)

# %% [markdown]
# ![image.png](attachment:image.png)
